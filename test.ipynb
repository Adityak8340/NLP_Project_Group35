# %%
1+1
# Out:
# 2

# %%
import pandas as pd
import json

# Sample JSON data (you can replace this with your actual JSON data)
json_data = [
    {
        "containers": {
            "cna": {
                "affected": [
                    {
                        "product": "n/a",
                        "vendor": "n/a",
                        "versions": [
                            {
                                "status": "affected",
                                "version": "n/a"
                            }
                        ]
                    }
                ],
                "descriptions": [
                    {
                        "lang": "en",
                        "value": "Unspecified vulnerability in crontab in IBM AIX 3.2 allows local users to gain root privileges via unknown attack vectors."
                    }
                ],
                "problemTypes": [
                    {
                        "descriptions": [
                            {
                                "description": "n/a",
                                "lang": "en",
                                "type": "text"
                            }
                        ]
                    }
                ],
                "providerMetadata": {
                    "dateUpdated": "2022-10-03T16:23:42",
                    "orgId": "8254265b-2729-46b6-b9e3-3dfca2d5bfca",
                    "shortName": "mitre"
                },
                "references": [
                    {
                        "name": "CA-1992-10",
                        "tags": [
                            "third-party-advisory",
                            "x_refsource_CERT"
                        ],
                        "url": "http://www.cert.org/advisories/CA-1992-10.html"
                    },
                    {
                        "name": "357",
                        "tags": [
                            "vdb-entry",
                            "x_refsource_BID"
                        ],
                        "url": "http://www.securityfocus.com/bid/357"
                    }
                ],
                "x_legacyV4Record": {
                    "CVE_data_meta": {
                        "ASSIGNER": "cve@mitre.org",
                        "ID": "CVE-1999-1589",
                        "STATE": "PUBLIC"
                    },
                    "affects": {
                        "vendor": {
                            "vendor_data": [
                                {
                                    "product": {
                                        "product_data": [
                                            {
                                                "product_name": "n/a",
                                                "version": {
                                                    "version_data": [
                                                        {
                                                            "version_value": "n/a"
                                                        }
                                                    ]
                                                }
                                            }
                                        ]
                                    },
                                    "vendor_name": "n/a"
                                }
                            ]
                        }
                    },
                    "data_format": "MITRE",
                    "data_type": "CVE",
                    "data_version": "4.0",
                    "description": {
                        "description_data": [
                            {
                                "lang": "eng",
                                "value": "Unspecified vulnerability in crontab in IBM AIX 3.2 allows local users to gain root privileges via unknown attack vectors."
                            }
                        ]
                    },
                    "problemtype": {
                        "problemtype_data": [
                            {
                                "description": [
                                    {
                                        "lang": "eng",
                                        "value": "n/a"
                                    }
                                ]
                            }
                        ]
                    },
                    "references": {
                        "reference_data": [
                            {
                                "name": "CA-1992-10",
                                "refsource": "CERT",
                                "url": "http://www.cert.org/advisories/CA-1992-10.html"
                            },
                            {
                                "name": "357",
                                "refsource": "BID",
                                "url": "http://www.securityfocus.com/bid/357"
                            }
                        ]
                    }
                }
            },
            "adp": [
                {
                    "providerMetadata": {
                        "orgId": "af854a3a-2127-422b-91ae-364da2661108",
                        "shortName": "CVE",
                        "dateUpdated": "2024-08-01T17:18:07.672Z"
                    },
                    "title": "CVE Program Container",
                    "references": [
                        {
                            "name": "CA-1992-10",
                            "tags": [
                                "third-party-advisory",
                                "x_refsource_CERT",
                                "x_transferred"
                            ],
                            "url": "http://www.cert.org/advisories/CA-1992-10.html"
                        },
                        {
                            "name": "357",
                            "tags": [
                                "vdb-entry",
                                "x_refsource_BID",
                                "x_transferred"
                            ],
                            "url": "http://www.securityfocus.com/bid/357"
                        }
                    ]
                }
            ]
        },
        "cveMetadata": {
            "assignerOrgId": "8254265b-2729-46b6-b9e3-3dfca2d5bfca",
            "assignerShortName": "mitre",
            "cveId": "CVE-1999-1589",
            "datePublished": "2022-10-03T16:23:42",
            "dateReserved": "2022-10-03T00:00:00",
            "dateUpdated": "2024-08-01T17:18:07.672Z",
            "state": "PUBLISHED"
        },
        "dataType": "CVE_RECORD",
        "dataVersion": "5.1"
    }
    # Add more JSON objects here
]

# Function to flatten JSON data
def flatten_json(y):
    out = {}

    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '_')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + str(i) + '_')
                i += 1
        else:
            out[name[:-1]] = x

    flatten(y)
    return out

# Flatten each JSON object and convert to DataFrame
flat_json_data = [flatten_json(json_obj) for json_obj in json_data]
df = pd.DataFrame(flat_json_data)

# Display the DataFrame
print(df)
# Out:
#   containers_cna_affected_0_product containers_cna_affected_0_vendor  \
# 0                               n/a                              n/a
#
#   containers_cna_affected_0_versions_0_status  \
# 0                                    affected
#
#   containers_cna_affected_0_versions_0_version  \
# 0                                          n/a
#
#   containers_cna_descriptions_0_lang  \
# 0                                 en
#
#                  containers_cna_descriptions_0_value  \
# 0  Unspecified vulnerability in crontab in IBM AI...
#
#   containers_cna_problemTypes_0_descriptions_0_description  \
# 0                                                n/a
#
#   containers_cna_problemTypes_0_descriptions_0_lang  \
# 0                                                en
#
#   containers_cna_problemTypes_0_descriptions_0_type  \
# 0                                              text
#
#   containers_cna_providerMetadata_dateUpdated  ...  \
# 0                         2022-10-03T16:23:42  ...
#
#       containers_adp_0_references_1_url             cveMetadata_assignerOrgId  \
# 0  http://www.securityfocus.com/bid/357  8254265b-2729-46b6-b9e3-3dfca2d5bfca
#
#   cveMetadata_assignerShortName cveMetadata_cveId cveMetadata_datePublished  \
# 0                         mitre     CVE-1999-1589       2022-10-03T16:23:42
#
#   cveMetadata_dateReserved   cveMetadata_dateUpdated cveMetadata_state  \
# 0      2022-10-03T00:00:00  2024-08-01T17:18:07.672Z         PUBLISHED
#
#      dataType dataVersion
# 0  CVE_RECORD         5.1
#
# [1 rows x 62 columns]

# %%
import os
import json
import pandas as pd

# Function to flatten JSON data
def flatten_json(y):
    out = {}

    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '_')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + str(i) + '_')
                i += 1
        else:
            out[name[:-1]] = x

    flatten(y)
    return out

# Directory containing JSON files
# Use raw string or forward slashes to avoid issues with backslashes
json_directory = r'C:\Users\91978\Downloads\cvelistV5-main\cvelistV5-main\cves\1999\0xxx'

# List to store flattened JSON data
flat_json_data = []

# Read and flatten each JSON file in the directory
for filename in os.listdir(json_directory):
    if filename.endswith('.json'):
        file_path = os.path.join(json_directory, filename)
        with open(file_path, 'r') as file:
            json_obj = json.load(file)
            flat_json_data.append(flatten_json(json_obj))

# Convert the list of flattened JSON data to a DataFrame
df = pd.DataFrame(flat_json_data)

# Display the DataFrame
print(df)
# Out:
#     containers_cna_affected_0_product containers_cna_affected_0_vendor  \
# 0                                 n/a                              n/a
# 1                                 n/a                              n/a
# 2                                 n/a                              n/a
# 3                                 n/a                              n/a
# 4                                 n/a                              n/a
# ..                                ...                              ...
# 975                               n/a                              n/a
# 976                               n/a                              n/a
# 977                               n/a                              n/a
# 978                               n/a                              n/a
# 979                               n/a                              n/a
#
#     containers_cna_affected_0_versions_0_status  \
# 0                                      affected
# 1                                      affected
# 2                                      affected
# 3                                      affected
# 4                                      affected
# ..                                          ...
# 975                                    affected
# 976                                    affected
# 977                                    affected
# 978                                    affected
# 979                                    affected
#
#     containers_cna_affected_0_versions_0_version  \
# 0                                            n/a
# 1                                            n/a
# 2                                            n/a
# 3                                            n/a
# 4                                            n/a
# ..                                           ...
# 975                                          n/a
# 976                                          n/a
# 977                                          n/a
# 978                                          n/a
# 979                                          n/a
#
#     containers_cna_descriptions_0_lang  \
# 0                                   en
# 1                                   en
# 2                                   en
# 3                                   en
# 4                                   en
# ..                                 ...
# 975                                 en
# 976                                 en
# 977                                 en
# 978                                 en
# 979                                 en
#
#                    containers_cna_descriptions_0_value  \
# 0    ip_input.c in BSD-derived TCP/IP implementatio...
# 1    Buffer overflow in NFS mountd gives root acces...
# 2    Execute commands as root via buffer overflow i...
# 3    MIME buffer overflow in email clients, e.g. So...
# 4    Arbitrary command execution via IMAP buffer ov...
# ..                                                 ...
# 975  Windows NT Local Security Authority (LSA) allo...
# 976  Buffer overflow in Infoseek Ultraseek search e...
# 977  wu-ftp with FTP conversion enabled allows an a...
# 978  Cisco Cache Engine allows an attacker to repla...
# 979  Microsoft SQL 7.0 server allows a remote attac...
#
#     containers_cna_problemTypes_0_descriptions_0_description  \
# 0                                                  n/a
# 1                                                  n/a
# 2                                                  n/a
# 3                                                  n/a
# 4                                                  n/a
# ..                                                 ...
# 975                                                n/a
# 976                                                n/a
# 977                                                n/a
# 978                                                n/a
# 979                                                n/a
#
#     containers_cna_problemTypes_0_descriptions_0_lang  \
# 0                                                  en
# 1                                                  en
# 2                                                  en
# 3                                                  en
# 4                                                  en
# ..                                                ...
# 975                                                en
# 976                                                en
# 977                                                en
# 978                                                en
# 979                                                en
#
#     containers_cna_problemTypes_0_descriptions_0_type  \
# 0                                                text
# 1                                                text
# 2                                                text
# 3                                                text
# 4                                                text
# ..                                                ...
# 975                                              text
# 976                                              text
# 977                                              text
# 978                                              text
# 979                                              text
#
#     containers_cna_providerMetadata_dateUpdated  ...  \
# 0                           2005-12-17T00:00:00  ...
# 1                           2005-11-02T10:00:00  ...
# 2                           2005-11-02T10:00:00  ...
# 3                           2018-10-12T19:57:01  ...
# 4                           2005-11-02T10:00:00  ...
# ..                                          ...  ...
# 975                         2005-11-02T10:00:00  ...
# 976                         2008-03-04T00:00:00  ...
# 977                         2004-09-02T09:00:00  ...
# 978                         2022-08-17T08:18:38  ...
# 979                         2005-11-02T10:00:00  ...
#
#     containers_adp_0_references_8_url containers_adp_0_references_9_name  \
# 0                                 NaN                                NaN
# 1                                 NaN                                NaN
# 2                                 NaN                                NaN
# 3                                 NaN                                NaN
# 4                                 NaN                                NaN
# ..                                ...                                ...
# 975                               NaN                                NaN
# 976                               NaN                                NaN
# 977                               NaN                                NaN
# 978                               NaN                                NaN
# 979                               NaN                                NaN
#
#     containers_adp_0_references_9_tags_0 containers_adp_0_references_9_tags_1  \
# 0                                    NaN                                  NaN
# 1                                    NaN                                  NaN
# 2                                    NaN                                  NaN
# 3                                    NaN                                  NaN
# 4                                    NaN                                  NaN
# ..                                   ...                                  ...
# 975                                  NaN                                  NaN
# 976                                  NaN                                  NaN
# 977                                  NaN                                  NaN
# 978                                  NaN                                  NaN
# 979                                  NaN                                  NaN
#
#     containers_adp_0_references_9_tags_2 containers_adp_0_references_9_url  \
# 0                                    NaN                               NaN
# 1                                    NaN                               NaN
# 2                                    NaN                               NaN
# 3                                    NaN                               NaN
# 4                                    NaN                               NaN
# ..                                   ...                               ...
# 975                                  NaN                               NaN
# 976                                  NaN                               NaN
# 977                                  NaN                               NaN
# 978                                  NaN                               NaN
# 979                                  NaN                               NaN
#
#     containers_cna_references_3_tags_2 containers_adp_0_references_3_tags_3  \
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
# 3                                  NaN                                  NaN
# 4                                  NaN                                  NaN
# ..                                 ...                                  ...
# 975                                NaN                                  NaN
# 976                                NaN                                  NaN
# 977                                NaN                                  NaN
# 978                                NaN                                  NaN
# 979                                NaN                                  NaN
#
#     containers_cna_references_4_tags_2 containers_adp_0_references_4_tags_3
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
# 3                                  NaN                                  NaN
# 4                                  NaN                                  NaN
# ..                                 ...                                  ...
# 975                                NaN                                  NaN
# 976                                NaN                                  NaN
# 977                                NaN                                  NaN
# 978                                NaN                                  NaN
# 979                                NaN                                  NaN
#
# [980 rows x 377 columns]

# %%
df.head()
# Out:
#   containers_cna_affected_0_product containers_cna_affected_0_vendor  \
# 0                               n/a                              n/a
# 1                               n/a                              n/a
# 2                               n/a                              n/a
# 3                               n/a                              n/a
# 4                               n/a                              n/a
#
#   containers_cna_affected_0_versions_0_status  \
# 0                                    affected
# 1                                    affected
# 2                                    affected
# 3                                    affected
# 4                                    affected
#
#   containers_cna_affected_0_versions_0_version  \
# 0                                          n/a
# 1                                          n/a
# 2                                          n/a
# 3                                          n/a
# 4                                          n/a
#
#   containers_cna_descriptions_0_lang  \
# 0                                 en
# 1                                 en
# 2                                 en
# 3                                 en
# 4                                 en
#
#                  containers_cna_descriptions_0_value  \
# 0  ip_input.c in BSD-derived TCP/IP implementatio...
# 1  Buffer overflow in NFS mountd gives root acces...
# 2  Execute commands as root via buffer overflow i...
# 3  MIME buffer overflow in email clients, e.g. So...
# 4  Arbitrary command execution via IMAP buffer ov...
#
#   containers_cna_problemTypes_0_descriptions_0_description  \
# 0                                                n/a
# 1                                                n/a
# 2                                                n/a
# 3                                                n/a
# 4                                                n/a
#
#   containers_cna_problemTypes_0_descriptions_0_lang  \
# 0                                                en
# 1                                                en
# 2                                                en
# 3                                                en
# 4                                                en
#
#   containers_cna_problemTypes_0_descriptions_0_type  \
# 0                                              text
# 1                                              text
# 2                                              text
# 3                                              text
# 4                                              text
#
#   containers_cna_providerMetadata_dateUpdated  ...  \
# 0                         2005-12-17T00:00:00  ...
# 1                         2005-11-02T10:00:00  ...
# 2                         2005-11-02T10:00:00  ...
# 3                         2018-10-12T19:57:01  ...
# 4                         2005-11-02T10:00:00  ...
#
#   containers_adp_0_references_8_url containers_adp_0_references_9_name  \
# 0                               NaN                                NaN
# 1                               NaN                                NaN
# 2                               NaN                                NaN
# 3                               NaN                                NaN
# 4                               NaN                                NaN
#
#   containers_adp_0_references_9_tags_0 containers_adp_0_references_9_tags_1  \
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
# 3                                  NaN                                  NaN
# 4                                  NaN                                  NaN
#
#   containers_adp_0_references_9_tags_2 containers_adp_0_references_9_url  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                  NaN                               NaN
#
#   containers_cna_references_3_tags_2 containers_adp_0_references_3_tags_3  \
# 0                                NaN                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
#
#   containers_cna_references_4_tags_2 containers_adp_0_references_4_tags_3
# 0                                NaN                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
#
# [5 rows x 377 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Columns: 377 entries, containers_cna_affected_0_product to containers_adp_0_references_4_tags_3
# dtypes: float64(1), object(376)
# memory usage: 2.8+ MB

# %%
null_values = df.isnull().sum()
print(null_values)
# Out:
# containers_cna_affected_0_product                31
# containers_cna_affected_0_vendor                 31
# containers_cna_affected_0_versions_0_status      31
# containers_cna_affected_0_versions_0_version     31
# containers_cna_descriptions_0_lang               31
#                                                ...
# containers_adp_0_references_9_url               979
# containers_cna_references_3_tags_2              977
# containers_adp_0_references_3_tags_3            977
# containers_cna_references_4_tags_2              979
# containers_adp_0_references_4_tags_3            979
# Length: 377, dtype: int64

# %%
print(df.describe())
# Out:
#        containers_adp_1_metrics_0_cvssV3_1_baseScore
# count                                      11.000000
# mean                                        8.545455
# std                                         0.895950
# min                                         7.300000
# 25%                                         8.100000
# 50%                                         8.400000
# 75%                                         9.100000
# max                                         9.800000

# %%
# missing values heatmap
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 10))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()

# %%
# correlation matrix heatmap

corr_matrix = df.corr().abs()  # Absolute values to see strength of correlations
plt.figure(figsize=(20, 15))
sns.heatmap(corr_matrix, annot=False, cmap='coolwarm')
plt.title('Correlation Matrix Heatmap')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 3
#       1 # correlation matrix heatmap
# ----> 3 corr_matrix = df.corr().abs()  # Absolute values to see strength of correlations
#       4 plt.figure(figsize=(20, 15))
#       5 sns.heatmap(corr_matrix, annot=False, cmap='coolwarm')
#
# File c:\Users\91978\Desktop\nlp-project-grp_35\nlp\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\91978\Desktop\nlp-project-grp_35\nlp\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File c:\Users\91978\Desktop\nlp-project-grp_35\nlp\Lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File c:\Users\91978\Desktop\nlp-project-grp_35\nlp\Lib\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: 'n/a'

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca_result = pca.fit_transform(df.dropna())  # Drop NaNs before PCA

plt.figure(figsize=(10, 8))
plt.scatter(pca_result[:, 0], pca_result[:, 1], alpha=0.5)
plt.title('PCA - 2D Projection')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 4
#       1 from sklearn.decomposition import PCA
#       3 pca = PCA(n_components=2)
# ----> 4 pca_result = pca.fit_transform(df.dropna())  # Drop NaNs before PCA
#       6 plt.figure(figsize=(10, 8))
#       7 plt.scatter(pca_result[:, 0], pca_result[:, 1], alpha=0.5)
#
# File c:\Users\91978\Desktop\nlp-project-grp_35\nlp\Lib\site-packages\sklearn\utils\_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#     314     if isinstance(data_to_wrap, tuple):
#     315         # only wrap the first output for cross decomposition
#     316         return_tuple = (
#     317             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     318             *data_to_wrap[1:],
#     319         )
#
# File c:\Users\91978\Desktop\nlp-project-grp_35\nlp\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\91978\Desktop\nlp-project-grp_35\nlp\Lib\site-packages\sklearn\decomposition\_pca.py:474, in PCA.fit_transform(self, X, y)
#     451 @_fit_context(prefer_skip_nested_validation=True)
#     452 def fit_transform(self, X, y=None):
#     453     """Fit the model with X and apply the dimensionality reduction on X.
#     454
#     455     Parameters
#    (...)
#     472     C-ordered array, use 'np.ascontiguousarray'.
#     473     """
# --> 474     U, S, _, X, x_is_centered, xp = self._fit(X)
#     475     if U is not None:
#     476         U = U[:, : self.n_components_]
#
# File c:\Users\91978\Desktop\nlp-project-grp_35\nlp\Lib\site-packages\sklearn\decomposition\_pca.py:511, in PCA._fit(self, X)
#     501     raise ValueError(
#     502         "PCA with svd_solver='arpack' is not supported for Array API inputs."
#     503     )
#     505 # Validate the data, without ever forcing a copy as any solver that
#     506 # supports sparse input data and the `covariance_eigh` solver are
#     507 # written in a way to avoid the need for any inplace modification of
#     508 # the input data contrary to the other solvers.
#     509 # The copy will happen
#     510 # later, only if needed, once the solver negotiation below is done.
# --> 511 X = self._validate_data(
#     512     X,
#     513     dtype=[xp.float64, xp.float32],
#     514     force_writeable=True,
#     515     accept_sparse=("csr", "csc"),
#     516     ensure_2d=True,
#     517     copy=False,
#     518 )
#     519 self._fit_svd_solver = self.svd_solver
#     520 if self._fit_svd_solver == "auto" and issparse(X):
#
# File c:\Users\91978\Desktop\nlp-project-grp_35\nlp\Lib\site-packages\sklearn\base.py:633, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     631         out = X, y
#     632 elif not no_val_X and no_val_y:
# --> 633     out = check_array(X, input_name="X", **check_params)
#     634 elif no_val_X and not no_val_y:
#     635     out = _check_y(y, **check_params)
#
# File c:\Users\91978\Desktop\nlp-project-grp_35\nlp\Lib\site-packages\sklearn\utils\validation.py:1087, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1085     n_samples = _num_samples(array)
#    1086     if n_samples < ensure_min_samples:
# -> 1087         raise ValueError(
#    1088             "Found array with %d sample(s) (shape=%s) while a"
#    1089             " minimum of %d is required%s."
#    1090             % (n_samples, array.shape, ensure_min_samples, context)
#    1091         )
#    1093 if ensure_min_features > 0 and array.ndim == 2:
#    1094     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0, 377)) while a minimum of 1 is required by PCA.
